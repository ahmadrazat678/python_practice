# %% [markdown]
# # Python Practice Tasks Notebook
# Each topic contains 10 practice tasks.

# %% [markdown]
# ## Day 3
# **Values, Expressions, Statements**

# %%
# Tasks:
# 1. Print any integer number
# 2. Print a floating‑point number
# 3. Print a Boolean value
# 4. Store your age in a variable and print it
# 5. Add two numbers and print result
# 6. Multiply two numbers
# 7. Compare two numbers using > operator
# 8. Create a string variable with your name
# 9. Print sum of 3 + 7 * 2
# 10. Check if 10 equals 10

# %% [markdown]
# ## Day 3
# **String Operations**

# %%
# Tasks:
# 1. Create a string "Python"
# 2. Concatenate your name with " Khan"
# 3. Repeat a string 3 times
# 4. Print first character of a string
# 5. Slice first 4 characters
# 6. Find length of string
# 7. Convert string to lowercase
# 8. Convert string to uppercase
# 9. Replace one word with another
# 10. Check if substring exists

# %% [markdown]
# ## Day 3
# **Input, Type Casting, Comments**

# %%
# Tasks:
# 1. Take name input from user
# 2. Take age input and convert to int
# 3. Take decimal input and convert to float
# 4. Convert string "100" to integer
# 5. Convert number 50 to string
# 6. Write a single‑line comment
# 7. Add two input numbers
# 8. Convert 0 to Boolean
# 9. Convert 1 to Boolean
# 10. Print greeting using input name

# %% [markdown]
# ## Day 4
# **Lists & Tuples**

# %%
# Tasks:
# 1. Create a list of 5 numbers
# 2. Append a new number
# 3. Remove one element
# 4. Access first element
# 5. Find list length
# 6. Create a tuple of 3 items
# 7. Access tuple element
# 8. Create list of names
# 9. Change second item in list
# 10. Try changing tuple value (observe error)

# %% [markdown]
# ## Day 4
# **Dictionaries & Sets**

# %%
# Tasks:
# 1. Create dictionary with name and age
# 2. Access value by key
# 3. Add new key‑value pair
# 4. Print all keys
# 5. Print dictionary length
# 6. Create set with duplicate values
# 7. Add new value to set
# 8. Remove value from set
# 9. Check membership in set
# 10. Convert list to set

# %% [markdown]
# ## Day 5
# **Conditional Execution**

# %%
# Tasks:
# 1. Check if number is positive
# 2. Check if number is even or odd
# 3. Compare two numbers
# 4. Print grade using if‑elif
# 5. Use else when condition false


   #levea for now 
# 6. Break loop at specific value
# 7. Skip number using continue
# 8. Use pass in loop
# 9. Print numbers 1‑5 using loop
# 10. Stop loop when value equals 3

# %% [markdown]
# ## Nested Conditionals

# %%
# Tasks:
# 1. Check if number is positive and even
# 2. Check age >=18 and citizen
# 3. Classify marks (pass & grade)
# 4. Check number >0 and divisible by 5
# 5. Password + OTP check simulation
# 6. Salary > threshold then tax bracket
# 7. Check login + admin role
# 8. Weather + temperature decision
# 9. Student pass + distinction
# 10. Product in stock + discount

# %% [markdown]
# ## Conditional (Ternary) Expression

# %%
# Tasks:
# 1. Check positive or negative
# 2. Adult or minor
# 3. Even or odd
# 4. Find maximum of two numbers
# 5. Pass or fail by marks
# 6. Hot or cool by temperature
# 7. Zero or non‑zero
# 8. Grade Excellent or Good
# 9. Light On or Off
# 10. Logged in or Login first
