# %%
# check if num is positive negative or zero.
num = int(input("Enter Number: "))
if num > 0:
    print("Positive Number")
elif num < 0:
    print("Negative Number")
else:  
     print("Number is Zero")
# Out:
# Number is Zero

# %%
# age check for voting eligibility.
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %%
a = int(input("Enter your marks1: "))
b = int(input("Enter your marks2: "))
c = int(input("Enter your marks3: "))
d = int(input("Enter your marks4: "))
e = int(input("Enter your marks5: "))
f = int(input("Enter your marks6: "))
if a >= 90 and b >= 90 and c >= 90 and d >= 90 and e >= 90 and f >= 90:
    print("Grade A")
elif a >= 80 and b >= 80 and c >= 80 and d >= 80 and e >= 80 and f >= 80:
    print("Grade B")    
elif a >= 70 and b >= 70 and c >= 70 and d >= 70 and e >= 70 and f >= 70:
    print("Grade C")
elif a >= 60 and b >= 60 and c >= 60 and d >= 60 and e >= 60 and f >= 60:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Grade F

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0): 
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# 2026 is not a leap year.

# %%
# check triangle type by sides.
side1 = float(input("Enter the length of the first side: "))
side2 = float(input("Enter the length of the second side: "))
side3 = float(input("Enter the length of the third side: "))
if side1 == side2 == side3:
    print("The triangle is an equilateral triangle.")
elif side1 == side2 or side1 == side3 or side2 == side3:
    print("The triangle is an isosceles triangle.")
else:
    print("The triangle is a scalene triangle.")

# %%
# check weather temperature and say weather type.
temp = int(input("Enter temperature in Celsius: "))
if temp < 0:
    print("Freezing weather")   
elif temp >= 0 and temp < 10:
    print("Very Cold weather")
elif temp >= 10 and temp < 20:
    print("Cold weather")
elif temp >= 20 and temp < 30:
    print("Normal in Temp")
elif temp >= 30 and temp < 40:
    print("Hot weather")
else:
    print("Very Hot weather")
# Out:
# Freezing weather
