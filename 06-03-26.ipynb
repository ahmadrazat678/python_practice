# %%
import numpy as np
import pandas as pd


df1 = pd.DataFrame({"Duration": [16, 55, 35, 45],
                    "Date": ["2021-01-01", "2022-01-02", "2023-01-03", "2024-01-04"],
                    "Pulse": [110, 117, 103, 109],
                    "Maxpulse": [130, 145, 135, 127],
                    "Calories": [409.1, 479.0, 340.0, 282.4]})
df1
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        16  2021-01-01    110       130     409.1
# 1        55  2022-01-02    117       145     479.0
# 2        35  2023-01-03    103       135     340.0
# 3        45  2024-01-04    109       127     282.4
