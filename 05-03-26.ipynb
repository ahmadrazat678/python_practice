# %%
import numpy as np
l1 = [1, 2, 3, 4, 5]
arr = np.array(l1)
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
import numpy as np
import pandas as pd

df1 = pd.Series([1,2,3,4,5])
print(df1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df1 = pd.DataFrame({"name":["ali","abss","zyz"],
                    "age":[25,30,np.nan]})
df1
# Out:
#    name   age
# 0   ali  25.0
# 1  abss  30.0
# 2   zyz   NaN

# %%
df1.shape
# Out:
# (3, 2)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      str
#  1   age     2 non-null      float64
# dtypes: float64(1), str(1)
# memory usage: 180.0 bytes

# %%
df1.columns
# Out:
# Index(['name', 'age'], dtype='str')

# %%
df1.describe()
# Out:
#              age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df1.iloc[:,1:2]
# Out:
#     age
# 0  25.0
# 1  30.0
# 2   NaN

# %%
df1.loc[:, 'age']
# Out:
# 0    25.0
# 1    30.0
# 2     NaN
# Name: age, dtype: float64

# %%
df1["age"]
# Out:
# 0    25.0
# 1    30.0
# 2     NaN
# Name: age, dtype: float64

# %%
df1.head()
# Out:
#    name   age
# 0   ali  25.0
# 1  abss  30.0
# 2   zyz   NaN

# %%
df1.tail(1)
# Out:
#   name  age
# 2  zyz  NaN

# %%
# From dictionary
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'London']
})

# From list of dictionaries
df2 = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Age': [25, 30],
})

# From NumPy array
df3 = pd.DataFrame(np.random.randn(4, 3), 
                   columns=['A', 'B', 'C'],
                   index=['Row1', 'Row2', 'Row3', 'Row4'])

df2
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import numpy as np
import pandas as pd

df1 = pd.DataFrame({"name":["Ahmad", "Hamza", "Ahtesham", "Anees"],
                    "age": [20,17,22,21],
                    "qualification": ["BS.IT", "Pharm-D", "BS-CS", "Working"]})
df1
# Out:
#        name  age qualification
# 0     Ahmad   20         BS.IT
# 1     Hamza   17       Pharm-D
# 2  Ahtesham   22         BS-CS
# 3     Anees   21       Working

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4 non-null      str
#  1   age            4 non-null      int64
#  2   qualification  4 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 228.0 bytes

# %%
df1.describe()
# Out:
#              age
# count   4.000000
# mean   20.000000
# std     2.160247
# min    17.000000
# 25%    19.250000
# 50%    20.500000
# 75%    21.250000
# max    22.000000

# %%
df1.columns
# Out:
# Index(['name', 'age', 'qualification'], dtype='str')

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df1.shape
# Out:
# (4, 3)

# %%
df1.iloc[:,:1]
# Out:
#        name
# 0     Ahmad
# 1     Hamza
# 2  Ahtesham
# 3     Anees

# %%
df1.loc[:, "qualification"]
# Out:
# 0      BS.IT
# 1    Pharm-D
# 2      BS-CS
# 3    Working
# Name: qualification, dtype: str

# %%
#add null value in dataframe using random numbers
df1 = pd.DataFrame(np.random.randn(50,50))
df1.iloc[1:2] = np.nan
print(df1)
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.230881 -0.634613  1.537675 -0.043761 -2.079473  0.886108 -0.212255
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  -0.266656 -1.475593 -0.219749 -1.411609 -0.712306 -1.328480  0.279028
# 3  -1.454104  0.509354 -0.141759 -0.778674 -1.748803  2.090180  0.077524
# 4   0.640109 -2.874225 -0.631747  0.788270 -1.802723 -1.321664  1.720046
# 5   0.191019  0.463457  2.137611  0.619600 -1.182162  1.364809 -0.434413
# 6  -0.301270  0.853429  0.054175  0.704740 -0.017681 -0.087366  0.447666
# 7  -0.488628 -0.447809  0.501210 -0.121180  0.470958  0.415042  0.366231
# 8  -0.237824 -0.615331  0.100867  0.989695  1.837263 -1.398501 -0.720019
# 9  -0.886360 -1.087025 -0.726011  2.077700 -0.141796 -0.114708  0.752516
# 10  0.644600 -0.835886 -1.143064  1.474052 -0.500626  0.012930 -2.173387
# 11  0.297104 -0.352350  0.537246  0.265542 -1.374416  1.429960  0.799527
# ...
